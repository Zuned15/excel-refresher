# %% [markdown]
# # Assignment 1
# 1.the types of cell referencing are
#  - a) In relative cell referencing, the cells are not fixed. The cell         reference changes when the formula is copied to another cell. example: Z15
#
#   - b)  In absolute cell referencing, the cells are fixed.The reference doesn't change when formula is copied to another cell.example: $Z$17
#
#   - c) In mixed cell referencing,either the row is fixed or the column is fixed.example:$S23, R$23
#
# 2.=B2+B3
#
# 3.=AVERAGEIFS($O$3:$O$5,$N$3:$N$5,">100",$N$3:$N$5,"<300")
#
# 4.=COUNTA(B2:B51)
#
# 5.=$E2*$F2
#
# 6.=SUMIFS(H2:H51,C2:C51,"North",D2:D51,"Notebook")
